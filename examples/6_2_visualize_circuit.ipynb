# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import pennylane as qml
from vqa import transforms
from vqa.templates.circuits import BarrenPlateauCircuit
from vqa.templates.examples import h2_vqe_circuit
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# circuit = BarrenPlateauCircuit(num_layers=2, num_qubits=3)
circuit = h2_vqe_circuit(num_layers=2)
params = circuit.init(rng_key=1)

qnode = transforms.exp_val(circuit, circuit.H, device="qiskit.aer")
print(qnode(params))
# Out:
# converged SCF energy = -1.12606474197566
# 0.2957020431818147

# %%
transforms.draw(circuit)
# Out:
# <Wires = [0, 1, 2, 3]> wires

# %%
fun = transforms.exp_val(circuit, circuit.H)

# %%
print(qnode.device._circuit.qasm())  # circuit must be executed before qasm is available
# Out:
# OPENQASM 2.0;
# include "qelib1.inc";
# qreg q[4];
# creg c[4];
# x q[0];
# x q[1];
# rz(0.417022) q[0];
# ry(0.72032449) q[0];
# rz(0.00011437482) q[0];
# rz(0.30233257) q[1];
# ry(0.14675589) q[1];
# rz(0.092338595) q[1];
# rz(0.18626021) q[2];
# ry(0.34556073) q[2];
# rz(0.39676747) q[2];
# rz(0.53881673) q[3];
# ry(0.41919451) q[3];
# rz(0.6852195) q[3];
# cx q[0],q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# cx q[3],q[0];
# rz(0.20445225) q[0];
# ry(0.87811744) q[0];
# rz(0.027387593) q[0];
# rz(0.67046751) q[1];
# ry(0.4173048) q[1];
# rz(0.55868983) q[1];
# rz(0.14038694) q[2];
# ry(0.19810149) q[2];
# rz(0.80074457) q[2];
# rz(0.96826158) q[3];
# ry(0.31342418) q[3];
# rz(0.69232262) q[3];
# cx q[0],q[1];
# cx q[1],q[2];
# cx q[2],q[3];
# cx q[3],q[0];
# measure q[0] -> c[0];
# measure q[1] -> c[1];
# measure q[2] -> c[2];
# measure q[3] -> c[3];
